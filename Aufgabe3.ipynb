# %% [markdown]
# # Aufgabe 3

# %%
from sympy import *
u = Function('u')
x = Symbol('x')
g = Symbol('g')
equ = Eq(-diff(u(x),x,x), -g)
display(equ)
# Out:
# Eq(-Derivative(u(x), (x, 2)), -g)

# %%
sol = dsolve(equ.subs({g: 10}), u(x), ics = {u(0): 0, u(1): 0})
display(sol)
# Out:
# Eq(u(x), 5*x**2 - 5*x)

# %%
plotting.plot(sol.rhs, (x,0,1));
